# %%
import pandas as pd

dfp = pd.read_csv("proyectos.csv")
dfr = pd.read_csv("recursos.csv", decimal=',')
dfs = pd.read_csv("socios.csv", decimal=',')

dfr.head()
# Out:
#            número                                             nombre  \
# 0  75773-26740-LB                   Recurso contra Celite - Tilviche
# 1  34339-73469-DD       Recurso contra PureFunds ETFx HealthTech ETF
# 2  54011-96023-OK         Recurso contra RenaissanceRe Holdings Ltd.
# 3   2244-72747-GF               Recurso contra Sierra Oncology, Inc.
# 4  17957-30003-BH  Recurso contra Voya Global Equity Dividend and...
#
#       causa contaminante  área influencia (kms)  \
# 0               mal olor                  29.76
# 1                  ruido                  26.64
# 2  contaminación de agua                  41.70
# 3  contaminación de agua                  43.11
# 4              radiación                  36.27
#
#                                          descripción fecha apertura  \
# 0  Maecenas tristique, est et tempus semper, est ...     09/10/1995
# 1  Curabitur in libero ut massa volutpat convalli...     12/09/2010
# ...
